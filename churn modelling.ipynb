# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
df = pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
x_drop = df.drop(['Surname'],axis=1)
x_drop.head()
# Out:
#    RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602          619    France  Female   42       2
# 1          2    15647311          608     Spain  Female   41       1
# 2          3    15619304          502    France  Female   42       8
# 3          4    15701354          699    France  Female   39       1
# 4          5    15737888          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Assume we want to encode the column at position 2 (third column)
# It's better to refer to the column by name if possible
column_to_encode = x_drop.columns[3]

# Apply LabelEncoder to the specified column
x_drop[column_to_encode] = le.fit_transform(x_drop[column_to_encode])

# Print the first few rows of the dataframe to check
print(x_drop.head())
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602          619          0  Female   42       2
# 1          2    15647311          608          2  Female   41       1
# 2          3    15619304          502          0  Female   42       8
# 3          4    15701354          699          0  Female   39       1
# 4          5    15737888          850          2  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df_dummies = pd.get_dummies(x_drop, columns=['Gender'])

boolean_columns = df_dummies.select_dtypes(include=['bool']).columns
df_dummies[boolean_columns] = df_dummies[boolean_columns].astype(int)

print(df_dummies)
# Out:
#       RowNumber  CustomerId  CreditScore  Geography  Age  Tenure    Balance  \
# 0             1    15634602          619          0   42       2       0.00
# 1             2    15647311          608          2   41       1   83807.86
# 2             3    15619304          502          0   42       8  159660.80
# 3             4    15701354          699          0   39       1       0.00
# 4             5    15737888          850          2   43       2  125510.82
# ...         ...         ...          ...        ...  ...     ...        ...
# 9995       9996    15606229          771          0   39       5       0.00
# 9996       9997    15569892          516          0   35      10   57369.61
# 9997       9998    15584532          709          0   36       7       0.00
# 9998       9999    15682355          772          1   42       3   75075.31
# 9999      10000    15628319          792          0   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
#       Gender_Female  Gender_Male
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 1            0
# 4                 1            0
# ...             ...          ...
# 9995              0            1
# 9996              0            1
# 9997              1            0
# 9998              0            1
# 9999              1            0
#
# [10000 rows x 14 columns]

# %%
x=df_dummies.iloc[:,:-1].values
y=df_dummies.iloc[:,-1].values
x
# Out:
# array([[1.0000000e+00, 1.5634602e+07, 6.1900000e+02, ..., 1.0134888e+05,
#         1.0000000e+00, 1.0000000e+00],
#        [2.0000000e+00, 1.5647311e+07, 6.0800000e+02, ..., 1.1254258e+05,
#         0.0000000e+00, 1.0000000e+00],
#        [3.0000000e+00, 1.5619304e+07, 5.0200000e+02, ..., 1.1393157e+05,
#         1.0000000e+00, 1.0000000e+00],
#        ...,
#        [9.9980000e+03, 1.5584532e+07, 7.0900000e+02, ..., 4.2085580e+04,
#         1.0000000e+00, 1.0000000e+00],
#        [9.9990000e+03, 1.5682355e+07, 7.7200000e+02, ..., 9.2888520e+04,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+04, 1.5628319e+07, 7.9200000e+02, ..., 3.8190780e+04,
#         0.0000000e+00, 1.0000000e+00]])

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
null_values = df.isnull().sum()
print(null_values)
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# Generate synthetic data
df_dummies, y = make_regression(n_samples=1000, n_features=20, noise=0.1)
x_train, x_test, y_train, y_test = train_test_split(df_dummies, y_binary, test_size=0.2, random_state=42)

# Initialize the Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Fit the model
gbr.fit(x_train, y_train)

# Predict
y_pred = gbr.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.27148864719274407

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10]
}

# Initialize the Gradient Boosting Regressor
gbr = GradientBoostingRegressor(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=gbr, param_grid=param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Best parameters
print(f"Best parameters: {grid_search.best_params_}")

# Best model
best_gbr = grid_search.best_estimator_

# Predict with the best model
y_pred = best_gbr.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error after tuning: {mse}")
# Out:
# Best parameters: {'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 50}
# Mean Squared Error after tuning: 0.2584766308153547

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
model = LogisticRegression()
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


kfold = KFold(n_splits=15, shuffle=True, random_state=42)
# Train the model
model.fit(x_train, y_train)


# Make predictions
y_pred = model.predict(x_test)


# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.7783333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      1370
#            1       0.80      0.80      0.80      1630
#
#     accuracy                           0.78      3000
#    macro avg       0.78      0.78      0.78      3000
# weighted avg       0.78      0.78      0.78      3000
# C:\Users\MOKSHYA SAHU\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
smote = SMOTE(sampling_strategy=0.8 , random_state=42)
x_train_r, y_train_r = smote.fit_resample(x_train, y_train)



# Standardize the features
scaler = StandardScaler()
x_train_r = scaler.fit_transform(x_train_r)
x_test = scaler.transform(x_test)
model = LogisticRegression()
kfold = KFold(n_splits=15, shuffle=True, random_state=42)
# Train the model
model.fit(x_train_r, y_train_r)


# Make predictions
y_pred = model.predict(x_test)


# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 2
#       1 smote = SMOTE(sampling_strategy=0.8 , random_state=42)
# ----> 2 x_train_r, y_train_r = smote.fit_resample(x_train, y_train)
#       6 # Standardize the features
#       7 scaler = StandardScaler()
#
# File ~\New folder\Lib\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File ~\New folder\Lib\site-packages\imblearn\base.py:108, in SamplerMixin.fit_resample(self, X, y)
#     105 arrays_transformer = ArraysTransformer(X, y)
#     106 X, y, binarize_y = self._check_X_y(X, y)
# --> 108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
#     112 output = self._fit_resample(X, y)
#     114 y_ = (
#     115     label_binarize(output[1], classes=np.unique(y)) if binarize_y else output[1]
#     116 )
#
# File ~\New folder\Lib\site-packages\imblearn\utils\_validation.py:571, in check_sampling_strategy(sampling_strategy, y, sampling_type, **kwargs)
#     564     if sampling_strategy <= 0 or sampling_strategy > 1:
#     565         raise ValueError(
#     566             f"When 'sampling_strategy' is a float, it should be "
#     567             f"in the range (0, 1]. Got {sampling_strategy} instead."
#     568         )
#     569     return OrderedDict(
#     570         sorted(
# --> 571             _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#     572         )
#     573     )
#     574 elif callable(sampling_strategy):
#     575     sampling_strategy_ = sampling_strategy(y, **kwargs)
#
# File ~\New folder\Lib\site-packages\imblearn\utils\_validation.py:410, in _sampling_strategy_float(sampling_strategy, y, sampling_type)
#     404     sampling_strategy_ = {
#     405         key: int(n_sample_majority * sampling_strategy - value)
#     406         for (key, value) in target_stats.items()
#     407         if key != class_majority
#     408     }
#     409     if any([n_samples <= 0 for n_samples in sampling_strategy_.values()]):
# --> 410         raise ValueError(
#     411             "The specified ratio required to remove samples "
#     412             "from the minority class while trying to "
#     413             "generate new samples. Please increase the "
#     414             "ratio."
#     415         )
#     416 elif sampling_type == "under-sampling":
#     417     n_sample_minority = min(target_stats.values())
#
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.

# %%
smote = SMOTE( random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train)
scaler = StandardScaler()
x_train_resampled = scaler.fit_transform(x_train_resampled)
x_test = scaler.transform(x_test)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train_resampled, y_train_resampled)
y_pred = model.predict(x_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.metrics import accuracy_score, classification_report

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1370
#            1       1.00      1.00      1.00      1630
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
# Accuracy: 1.0

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

scaler = StandardScaler()
x_train_imputed = scaler.fit_transform(x_train_imputed)
x_test_imputed = scaler.transform(x_test_imputed)


svm_classifier = SVC(kernel='linear', C=1.0, random_state=42)
svm_classifier.fit(x_train_imputed, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = svm_classifier.predict(x_test_imputed)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1370
#            1       1.00      1.00      1.00      1630
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE


# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
x_train_r, y_train_r = smote.fit_resample(x_train, y_train)

print("Class distribution after SMOTE:", pd.Series(y_train_r).value_counts())

# Standardize the features
scaler = StandardScaler()
x_train_r = scaler.fit_transform(x_train_r)
x_test = scaler.transform(x_test)

# Train the SVM model
svm_classifier = SVC(kernel='linear', C=1.0, random_state=42)
svm_classifier.fit(x_train_r, y_train_r)

# Make predictions and evaluate the model
y_pred = svm_classifier.predict(x_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
# Out:
# Class distribution after SMOTE: 0    3827
# 1    3827
# Name: count, dtype: int64
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1370
#            1       1.00      1.00      1.00      1630
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
